# %% [markdown]
# <a href="https://colab.research.google.com/github/shravani2022/Project/blob/main/plotting_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("/content/data-1.csv")
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df.plot()
df.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-bb76a30db107> in <cell line: 2>()
#       1 df.plot()
# ----> 2 df.show()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'show'

# %% [markdown]
# # New section

# %%
df.plot(kind = "scatter",x="Duration" , y="Calories",color="red",marker="*")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-4f3f74f45110> in <cell line: 2>()
#       1 df.plot(kind = "scatter",x="Duration" , y="Calories",color="red",marker="*")
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
# Create a histogram of a feature
import matplotlib.pyplot as plt
plt.hist(df['Duration'])
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


df["Duration"].plot(kind = 'hist')

plt.show()
