# %% [markdown]
# <a href="https://colab.research.google.com/github/shravani2022/Project/blob/main/instagram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv("/content/insta.csv", encoding="latin1")
df
# Out:
#      Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 0           3920       2586           1028           619          56     98
# 1           5394       2727           1838          1174          78    194
# 2           4021       2085           1188             0         533     41
# 3           4528       2700            621           932          73    172
# 4           2518       1704            255           279          37     96
# ..           ...        ...            ...           ...         ...    ...
# 114        13700       5185           3041          5352          77    573
# 115         5731       1923           1368          2266          65    135
# 116         4139       1133           1538          1367          33     36
# 117        32695      11815           3147         17414         170   1095
# 118        36919      13473           4176         16444        2547    653
#
#      Comments  Shares  Likes  Profile Visits  Follows  \
# ...

# %%
df.isnull().sum()
# Out:
# Impressions       0
# From Home         0
# From Hashtags     0
# From Explore      0
# From Other        0
# Saves             0
# Comments          0
# Shares            0
# Likes             0
# Profile Visits    0
# Follows           0
# Caption           0
# Hashtags          0
# dtype: int64

# %%
df.head()
# Out:
#    Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 0         3920       2586           1028           619          56     98
# 1         5394       2727           1838          1174          78    194
# 2         4021       2085           1188             0         533     41
# 3         4528       2700            621           932          73    172
# 4         2518       1704            255           279          37     96
#
#    Comments  Shares  Likes  Profile Visits  Follows  \
# 0         9       5    162              35        2
# 1         7      14    224              48       10
# 2        11       1    131              62       12
# 3        10       7    213              23        8
# 4         5       4    123               8        0
#
#                                              Caption  \
# 0  Here are some of the most important data visua...
# 1  Here are some of the best data science project...
# ...

# %%
df.tail()
# Out:
#      Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 114        13700       5185           3041          5352          77    573
# 115         5731       1923           1368          2266          65    135
# 116         4139       1133           1538          1367          33     36
# 117        32695      11815           3147         17414         170   1095
# 118        36919      13473           4176         16444        2547    653
#
#      Comments  Shares  Likes  Profile Visits  Follows  \
# 114         2      38    373              73       80
# 115         4       1    148              20       18
# 116         0       1     92              34       10
# 117         2      75    549             148      214
# 118         5      26    443             611      228
#
#                                                Caption  \
# 114  Here are some of the best data science certifi...
# 115  Clustering is a machine learning technique use...
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 114    False
# 115    False
# 116    False
# 117    False
# 118    False
# Length: 119, dtype: bool

# %%
df.shape
# Out:
# (119, 13)

# %%
df.duplicated().sum()
# Out:
# 17

# %%
#Analyze the distribution of impressions received from home
plt.figsize = (10,8)
plt.style.use("fivethirtyeight")
plt.title(" distribution of impressions received from home")
sns.distplot(df["From Home"],color="brown",kde=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-bca8827454b5> in <cell line: 4>()
#       2 plt.figsize = (10,8)
#       3 plt.style.use("fivethirtyeight")
# ----> 4 plt.title(" distribution of impressions received from home")
#       5 sns.distplot(df["From Home"],color="brown",kde=True)
#       6 plt.show()
#
# TypeError: 'str' object is not callable

# %% [markdown]
# ANALYSIS :
# The impressions we get from the hashtag section on instagram shows how much my post reach my followers.
#  from the results , we can say hard to reach all the followers on the daily basis further to inspect the analysis thorolly
#  lets have a look at distribution of the impressions recieved from explore

# %%
plt.figsize = (10,8)
plt.style.use("fivethirtyeight")
plt.title("IMPRESSIONS RECEIVED FROM HASHTAG.")
sns.distplot(df["From Hashtags"],color= "red")
plt.show()
# Out:
# <ipython-input-42-3b62e8fab0b3>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["From Hashtags"])

# %% [markdown]
# Analysis -
# The impression we received from the instagram shows how much my hashtags reach my followers .
#
#
# From the graph we can say its difficult to reach followers on the daily basis
#
# Hashtags are tools we use to categorize our posts on Instagram so that we can reach more people based on the kind of content we are creating.
#
#  Looking at hashtag impressions shows that not all posts can be reached using hashtags, but many new users can be reached from hashtags.

# %%
plt.figure(figsize=(10,8))
plt.style.use("fivethirtyeight") #fivethirtyeight is a website
sns.distplot(df["From Explore"])
plt.show()
# Out:
# <ipython-input-58-a2ab5fa67fba>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["From Explore"])

# %% [markdown]
# Analysis - The impression we received from the graph shows how many users explore the instagram id
#
# - By the technical point of view, the explore section of the Instagram
#  is the recommendation system of instagram.
#
# - It recommends post to the users based on their preferences and intrest
#
# - from the impressions we have received from explore section , we can say that the instagram doesn't recommend our post to many users i.e the explore section recommendation engine has put some restrictions to some new users.
#
# - But the other part of above scenario tells us that some posts have received a good reach from the explore section .
#
# - As compared to that of hashtag it is still very low

# %%
#find percentage of impression from various sources of instagram
Home = df["From Home"].sum()
Hashtags = df["From Hashtags"].sum()
Explore = df["From Explore"].sum()
Other = df["From Other"].sum()


figure = px.pie(df,values=[Home,Hashtags,Explore,Other],names=["Home","Hashtags","Explore","Other"],color=["green","blue","red","yellow"],title="Percentage of impression from various sources of instagram,",hole = 0.5)
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Analysis -
# - The Above plot shows that almost 44 percentage  of home  reached from the followers
#
# - Hashtag reached upto 33.6 % percentage from followers
#
# - Explore reached 19.2 % of followers
#
# - Others reached 3.05 % .

# %%
#Lets create a word cloud from caption column as it as more columns in instragram post.

text = " ".join(i for i in df.Caption)
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords=stopwords,background_color="white").generate(text)
plt.style.use("classic")
plt.figure(figsize=(12,10))
plt.axis("off")
plt.imshow(wordcloud)
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
text = " ".join(i for i in df.Hashtags)
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords=stopwords,background_color="white").generate(text)
plt.style.use("classic")
plt.figure(figsize=(12,10))
plt.axis("off")
plt.imshow(wordcloud)
plt.show()

# %%
#analysis relationship
figure = px.scatter(df,x ="Impressions",y="Likes",size="Likes",trendline ="ols",title="Relationship between impressions and likes")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
figure = px.scatter(df,x ="Impressions",y="Comments",size="Comments",trendline ="ols",title="Relationship between impressions and comments")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
figure = px.scatter(df,x ="Impressions",y="Shares",size="Shares",trendline ="ols",title="Relationship between impressions and shares")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fugure = px.scatter(df,x ="Impressions",y="Saves",size="Saves",trendline ="ols",title="Relationship between impressions and saves")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Analyzing conversion rate
conversion_rate = (df["Follows"].sum() / df["Profile Visits"].sum()) * 100
print(conversion_rate)
# Out:
# 41.00265604249668

# %%
figure = px.scatter(df,x ="Profile Visits",y="Follows",size="Profile Visits",trendline ="ols",title="Relationship between follows and profile visits")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Prediction
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import PassiveAggressiveRegressor

# %% [markdown]
# #instagram reach prediction **model**

# %%
x = np.array(df[['Likes', 'Saves', 'Comments', 'Shares',
                   'Profile Visits', 'Follows']])
y = np.array(df["Impressions"])
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.10,random_state=50)

model = PassiveAggressiveRegressor()
model.fit(xtrain, ytrain)
model.score(xtest,ytest)
# Out:
# 0.7970128271965864

# %% [markdown]
# **Lets predict the reach of instagram post by giving input to the machine learning models **

# %%
# Features = [['Likes','Saves', 'Comments', 'Shares', 'Profile Visits', 'Follows']]
features = np.array([[282.0, 233.0, 4.0, 9.0, 165.0, 54.0]])
model.predict(features)
# Out:
# array([10263.09015751])
