# %% [markdown]
# <a href="https://colab.research.google.com/github/shravani2022/Project/blob/main/videogamesales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# > Add blockquote

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/vgsalesGlobale.csv")
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df["Year"].dtype
# Out:
# dtype('float64')

# %%
df.fillna(0, inplace=True)

# %%
#changing data type of float to int of year
df["Year"] = df["Year"].astype(int)
df
# Out:
#         Rank                                              Name Platform  Year  \
# 0          1                                        Wii Sports      Wii  2006
# 1          2                                 Super Mario Bros.      NES  1985
# 2          3                                    Mario Kart Wii      Wii  2008
# 3          4                                 Wii Sports Resort      Wii  2009
# 4          5                          Pokemon Red/Pokemon Blue       GB  1996
# ...      ...                                               ...      ...   ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA  2002
# 16594  16597                     Men in Black II: Alien Escape       GC  2003
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2  2008
# 16596  16599                                        Know How 2       DS  2010
# 16597  16600                                  Spirits & Spells      GBA  2003
#
# ...

# %%
#barplot of genre
sns.barplot(x=df["Genre"].value_counts().index, y=df["Genre"].value_counts(),palette="viridis")
plt.xlabels (rotation=45,ha="right")
plt.show()
# Out:
# <ipython-input-42-8e47fabfe7a1>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df["Genre"].value_counts().index, y=df["Genre"].value_counts(),palette="viridis")
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-8e47fabfe7a1> in <cell line: 3>()
#       1 #barplot of genre
#       2 sns.barplot(x=df["Genre"].value_counts().index, y=df["Genre"].value_counts(),palette="viridis")
# ----> 3 plt.xlabels (rotation=45,ha="right")
#       4 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlabels'

# %%
# Calculate genre counts
# Create the barplot with hue and legend
sns.barplot(x='Genre', y='Count', data=genre_counts, hue='Genre', palette='viridis', legend=False)
plt.xticks(rotation=45, ha='right')  # Rotate x-labels for better visibility
plt.grid()
plt.show()

# %%
#hist of year
sns.displot(data=df[:20],x="Year",color="green")
plt.grid()
plt.show()

# %%
#lineplot with hue
sns.lineplot(data=df[:20],x="Year",y="Global_Sales",hue="Genre")
# Out:
# <Axes: xlabel='Year', ylabel='Global_Sales'>

# %%
#lineplot of plotformy="Global_Sales",hue="
sns.lineplot(x='Year', y='Global_Sales', hue='Platform', data=df[:40])
plt.xlabel('Year')
plt.ylabel('Global Sales')
plt.title('Trend of Global Sales per Platform')
plt.legend(title='Platform')  # Customize the legend
plt.show()

# %%
sns.boxplot(x='Platform', y='Global_Sales', data=df[:20])
plt.xlabel('Platform')
plt.ylabel('Global Sales')
plt.title('Distribution of Global Sales by Platform')
plt.show()

# %%
sns.scatterplot(x='Year', y='Global_Sales', data=df[:20], color='green', size=10,palette="viridis")
# Out:
# <ipython-input-50-e4b319a7fd56>:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x='Year', y='Global_Sales', data=df[:20], color='green', size=10,palette="viridis")
# <Axes: xlabel='Year', ylabel='Global_Sales'>

# %%
#plot pie of genre
plt.pie(df["Genre"].value_counts(),labels=df["Genre"].value_counts().index,autopct="%1.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x79d37eebfe80>,
# ...
#  [Text(0.890359059728065, 0.6459572313707436, 'Action'),
#   Text(-0.14098088951152532, 1.0909282234833506, 'Sports'),
#   Text(-0.8628261066951454, 0.6822984021711452, 'Misc'),
#   Text(-1.0981313409109585, 0.06409023411644078, 'Role-Playing'),
#   Text(-0.9800788430959432, -0.4994451534610361, 'Shooter'),
#   Text(-0.6284777724368498, -0.9027821938611857, 'Adventure'),
#   Text(-0.14077451297515953, -1.09095487372146, 'Racing'),
#   Text(0.29952111976020795, -1.058436157176044, 'Platform'),
#   Text(0.6279649450683688, -0.9031389858517243, 'Simulation'),
#   Text(0.8832142054986449, -0.65569250964564, 'Fighting'),
#   Text(1.033606467004216, -0.3763743766080029, 'Strategy'),
#   Text(1.09333257635814, -0.12092922506190083, 'Puzzle')],
#  [Text(0.4856503962153081, 0.35234030802040556, '20.0%'),
#   Text(-0.07689866700628653, 0.5950517582636456, '14.1%'),
#   Text(-0.4706324218337156, 0.3721627648206246, '10.5%'),
# ...

# %%
sns.lineplot(data = df[:40],x="NA_Sales",y="Genre",marker = "*",color = "green",mec="blue")
plt.title("Line plot of NA_Sales vs Genre")
plt.xlabel("NA_Sales")
plt.ylabel("Genre")
plt.grid()
